# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

from fastai import *
from fastai.vision import *
from superRes.generators import *
from superRes.critics import *
from superRes.dataset import *
from superRes.loss import *
from superRes.save import *
from superRes.fid_loss import *
from superRes.ssim import *
from pathlib import Path

import torchvision
import geffnet # efficient/ mobile net

# %%
def get_data(bs:int, sz:int, keep_pct:float):
    return get_databunch(sz=sz, bs=bs, crappy_path=path_lowRes, 
                         good_path=path_fullRes, 
                         random_seed=None, keep_pct=keep_pct)

def get_DIV2k_data(pLow, bs:int, sz:int):
    """Given the path of low resolution images with a proper suffix
       returns a databunch
    """
    suffixes = {"dataset/DIV2K_train_LR_x8": "x8",
                "dataset/DIV2K_train_LR_difficult":"x4d", 
                "dataset/DIV2K_train_LR_mild":"x4m"}
    lowResSuffix = suffixes[str(pLow)]
    src = ImageImageList.from_folder(pLow).split_by_idxs(train_idx=list(range(0,800)), valid_idx=list(range(800,900)))
    
    data = (src.label_from_func(lambda x: path_fullRes/(x.name).replace(lowResSuffix, '')).transform(
            get_transforms(
                flip_vert=True,
                max_rotate=30,
                max_zoom=3.,
                max_lighting=.4,
                max_warp=.4,
                p_affine=.85
            ),
            size=sz,
            tfm_y=True,
        ).databunch(bs=bs, num_workers=8, no_check=True).normalize(imagenet_stats, do_y=True))
    data.c = 3
    return data

def get_DIV2k_data_patches(pLow, bs:int, sz:int):
    """Given the path of low resolution images with a proper suffix
       returns a databunch
    """
    src = ImageImageList.from_folder(pLow).split_by_idxs(train_idx=list(range(0,38304)), valid_idx=list(range(38304,43264)))
    
    data = (src.label_from_func(lambda x: path_fullRes_patches/x.name).transform(
            get_transforms(
                max_zoom=3.
            ),
            size=sz,
            tfm_y=True,
        ).databunch(bs=bs, num_workers=8, no_check=True).normalize(imagenet_stats, do_y=True))
    data.c = 3
    return data

def create_training_images(fn, i, p_hr, p_lr, size):
    """Create low quality images from folder p_hr in p_lr"""
    dest = p_lr/fn.relative_to(p_hr)
    dest.parent.mkdir(parents=True, exist_ok=True)
    img = PIL.Image.open(fn)
    targ_sz = resize_to(img, size, use_min=True)
    img = img.resize(targ_sz, resample=PIL.Image.BILINEAR).convert('RGB')
    img.save(dest, quality=60)

# %%
def do_fit(learn, epochs,save_name, lrs=slice(1e-3), pct_start=0.9):
    learn.fit_one_cycle(epochs, lrs, pct_start=pct_start)
    learn.save(save_name)
    learn.show_results(rows=1, imgsize=7)

# %%
path = Path('./dataset/')

path_fullRes_patches = path/"DIV2K_train_HR_Patches"/"64px"
path_lowRes_patches  = path/"DIV2K_train_LR_Patches"/"64px"

path_fullRes = path/'DIV2K_train_HR'
path_lowRes_mild = path/'DIV2K_train_LR_mild' # suffix "x4m" ~300px

proj_id = 'unet_superRes_mobilenetV3_Patches'

gen_name = proj_id + '_gen'
crit_name = proj_id + '_crit'

nf_factor = 2
pct_start = 1e-8

# %%
print(path_fullRes_patches)
# Out:
# dataset/DIV2K_train_HR_Patches

# %%
high_res = ImageList.from_folder(path_fullRes_patches, presort=True)
high_res.items[612864]
# Out:
# PosixPath('dataset/DIV2K_train_HR_Patches/800_patch_0_0.jpg')

# %%
lr = ImageList.from_folder(path_lowRes_patches)
hr = ImageList.from_folder(path_fullRes_patches)

lr[10].show()
hr[10].show()

# %%
model = geffnet.mobilenetv3_100
# model = models.resnet34
# model= geffnet.efficientnet_b4

# %%
# loss_func = FeatureLoss()
loss_func = msssim
# loss_func = calculate_frechet_distance

# %% [markdown]
# # 64px patch

# %%
bs=30
sz=64
lr = 1e-2
wd = 1e-3
epochs = 1

# %%
data_gen = get_DIV2k_data_patches(path_lowRes_patches, bs=bs, sz=sz)

# %%
data_gen.show_batch()

# %%
learn_gen = gen_learner_wide(data=data_gen,
                             gen_loss=loss_func,
                             arch = model,
                             nf_factor=nf_factor)

# %%
wandbCallbacks = False

if wandbCallbacks:
    import wandb
    from wandb.fastai import WandbCallback
    config={"batch_size": bs,
            "img_size": (sz, sz),
            "learning_rate": lr,
            "weight_decay": wd,
            "num_epochs": epochs
    }
    wandb.init(project='SuperRes', config=config, id="gen_mobilenetV3_SSIM"+ datetime.now().strftime('_%m-%d_%H:%M'))

    learn_gen.callback_fns.append(partial(WandbCallback, input_type='images'))

# %%
learn_gen.lr_find()
learn_gen.recorder.plot()
# learn_gen.summary()

# %%
do_fit(learn_gen, epochs, gen_name+"_256px_0", slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.297238</td>
#       <td>0.265326</td>
#       <td>1:13:33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 512px

# %%
bs=4
sz=512
epochs = 5

# %%
data_gen = get_DIV2k_data(path_lowRes_mild, bs, sz)

# %%
learn_gen.data = data_gen
learn_gen.freeze()
gc.collect()
# Out:
# 42

# %%
learn_gen.load(gen_name+"_256px_0")
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (800 items)
# x: ImageImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# Path: dataset/DIV2K_train_LR_mild;
#
# Valid: LabelList (100 items)
# x: ImageImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# Path: dataset/DIV2K_train_LR_mild;
#
# Test: None, model=DynamicUnetWide(
#   (layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (2): HardSwish()
#       (3): Sequential(
#         (0): Sequential(
#           (0): DepthwiseSeparableConv(
#             (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#             (bn1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): ReLU(inplace=True)
#             (se): Identity()
#             (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn2): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): Identity()
#           )
#         )
#         (1): Sequential(
#           (0): InvertedResidual(
#             (conv_pw): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): ReLU(inplace=True)
#             (conv_dw): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#             (bn2): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): ReLU(inplace=True)
#             (se): Identity()
#             (conv_pwl): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): InvertedResidual(
#             (conv_pw): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(72, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): ReLU(inplace=True)
#             (conv_dw): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (bn2): BatchNorm2d(72, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): ReLU(inplace=True)
#             (se): Identity()
#             (conv_pwl): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (2): Sequential(
#           (0): InvertedResidual(
#             (conv_pw): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(72, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): ReLU(inplace=True)
#             (conv_dw): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#             (bn2): BatchNorm2d(72, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): ReLU(inplace=True)
#             (se): SqueezeExcite(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_reduce): Conv2d(72, 18, kernel_size=(1, 1), stride=(1, 1))
#               (act1): ReLU(inplace=True)
#               (conv_expand): Conv2d(18, 72, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (conv_pwl): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): InvertedResidual(
#             (conv_pw): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(120, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): ReLU(inplace=True)
#             (conv_dw): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#             (bn2): BatchNorm2d(120, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): ReLU(inplace=True)
#             (se): SqueezeExcite(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_reduce): Conv2d(120, 30, kernel_size=(1, 1), stride=(1, 1))
#               (act1): ReLU(inplace=True)
#               (conv_expand): Conv2d(30, 120, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (conv_pwl): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): InvertedResidual(
#             (conv_pw): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(120, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): ReLU(inplace=True)
#             (conv_dw): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#             (bn2): BatchNorm2d(120, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): ReLU(inplace=True)
#             (se): SqueezeExcite(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_reduce): Conv2d(120, 30, kernel_size=(1, 1), stride=(1, 1))
#               (act1): ReLU(inplace=True)
#               (conv_expand): Conv2d(30, 120, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (conv_pwl): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): Sequential(
#           (0): InvertedResidual(
#             (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(240, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (bn2): BatchNorm2d(240, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): Identity()
#             (conv_pwl): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): InvertedResidual(
#             (conv_pw): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(200, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#             (bn2): BatchNorm2d(200, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): Identity()
#             (conv_pwl): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): InvertedResidual(
#             (conv_pw): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#             (bn2): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): Identity()
#             (conv_pwl): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): InvertedResidual(
#             (conv_pw): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#             (bn2): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): Identity()
#             (conv_pwl): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (4): Sequential(
#           (0): InvertedResidual(
#             (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(480, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (bn2): BatchNorm2d(480, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): SqueezeExcite(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_reduce): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#               (act1): HardSwish()
#               (conv_expand): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (conv_pwl): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): InvertedResidual(
#             (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (bn2): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): SqueezeExcite(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_reduce): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#               (act1): HardSwish()
#               (conv_expand): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (5): Sequential(
#           (0): InvertedResidual(
#             (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (bn2): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): SqueezeExcite(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_reduce): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#               (act1): HardSwish()
#               (conv_expand): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (conv_pwl): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): InvertedResidual(
#             (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): SqueezeExcite(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_reduce): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#               (act1): HardSwish()
#               (conv_expand): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (2): InvertedResidual(
#             (conv_pw): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#             (conv_dw): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (bn2): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): HardSwish()
#             (se): SqueezeExcite(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_reduce): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#               (act1): HardSwish()
#               (conv_expand): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (conv_pwl): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (6): Sequential(
#           (0): ConvBnAct(
#             (conv): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act1): HardSwish()
#           )
#         )
#       )
#     )
#     (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Sequential(
#       (0): Sequential(
#         (0): Conv2d(960, 1920, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): ReLU(inplace=True)
#         (2): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(1920, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): ReLU(inplace=True)
#         (2): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): UnetBlockWide(
#       (shuf): CustomPixelShuffle_ICNR(
#         (conv): Sequential(
#           (0): Conv2d(960, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (shuf): PixelShuffle(upscale_factor=2)
#         (pad): ReplicationPad2d((1, 0, 1, 0))
#         (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#         (relu): ReLU(inplace=True)
#       )
#       (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv): Sequential(
#         (0): Conv2d(272, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): ReLU(inplace=True)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (5): PixelShuffle_ICNR(
#       (conv): Sequential(
#         (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (shuf): PixelShuffle(upscale_factor=2)
#       (pad): ReplicationPad2d((1, 0, 1, 0))
#       (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#       (relu): ReLU(inplace=True)
#     )
#     (6): MergeLayer()
#     (7): SequentialEx(
#       (layers): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(259, 259, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(259, 259, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (2): MergeLayer()
#       )
#     )
#     (8): Sequential(
#       (0): Conv2d(259, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (9): SigmoidRange()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<function msssim at 0x7f5876c2dae8>, metrics=[], true_wd=True, bn_wd=True, wd=0.001, train_bn=True, path=PosixPath('dataset/DIV2K_train_LR_Patches'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (2): HardSwish()
#   (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#   (4): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace=True)
#   (6): Identity()
#   (7): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (8): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (9): Identity()
#   (10): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (11): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU(inplace=True)
#   (13): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#   (14): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (15): ReLU(inplace=True)
#   (16): Identity()
#   (17): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (18): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (19): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (20): BatchNorm2d(72, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (21): ReLU(inplace=True)
#   (22): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#   (23): BatchNorm2d(72, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU(inplace=True)
#   (25): Identity()
#   (26): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (27): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (28): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (29): BatchNorm2d(72, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (30): ReLU(inplace=True)
#   (31): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#   (32): BatchNorm2d(72, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (33): ReLU(inplace=True)
#   (34): AdaptiveAvgPool2d(output_size=1)
#   (35): Conv2d(72, 18, kernel_size=(1, 1), stride=(1, 1))
#   (36): ReLU(inplace=True)
#   (37): Conv2d(18, 72, kernel_size=(1, 1), stride=(1, 1))
#   (38): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (39): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (40): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (41): BatchNorm2d(120, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (42): ReLU(inplace=True)
#   (43): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#   (44): BatchNorm2d(120, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (45): ReLU(inplace=True)
#   (46): AdaptiveAvgPool2d(output_size=1)
#   (47): Conv2d(120, 30, kernel_size=(1, 1), stride=(1, 1))
#   (48): ReLU(inplace=True)
#   (49): Conv2d(30, 120, kernel_size=(1, 1), stride=(1, 1))
#   (50): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (51): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (52): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (53): BatchNorm2d(120, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (54): ReLU(inplace=True)
#   (55): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#   (56): BatchNorm2d(120, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (57): ReLU(inplace=True)
#   (58): AdaptiveAvgPool2d(output_size=1)
#   (59): Conv2d(120, 30, kernel_size=(1, 1), stride=(1, 1))
#   (60): ReLU(inplace=True)
#   (61): Conv2d(30, 120, kernel_size=(1, 1), stride=(1, 1))
#   (62): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (63): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (64): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (65): BatchNorm2d(240, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (66): HardSwish()
#   (67): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#   (68): BatchNorm2d(240, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (69): HardSwish()
#   (70): Identity()
#   (71): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (72): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (73): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (74): BatchNorm2d(200, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (75): HardSwish()
#   (76): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#   (77): BatchNorm2d(200, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (78): HardSwish()
#   (79): Identity()
#   (80): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (81): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (82): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (83): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (84): HardSwish()
#   (85): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#   (86): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (87): HardSwish()
#   (88): Identity()
#   (89): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (90): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (91): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (92): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (93): HardSwish()
#   (94): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#   (95): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (96): HardSwish()
#   (97): Identity()
#   (98): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (99): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (100): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (101): BatchNorm2d(480, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (102): HardSwish()
#   (103): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#   (104): BatchNorm2d(480, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (105): HardSwish()
#   (106): AdaptiveAvgPool2d(output_size=1)
#   (107): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#   (108): HardSwish()
#   (109): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#   (110): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (111): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (112): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (113): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (114): HardSwish()
#   (115): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#   (116): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (117): HardSwish()
#   (118): AdaptiveAvgPool2d(output_size=1)
#   (119): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#   (120): HardSwish()
#   (121): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#   (122): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (123): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (124): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (125): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (126): HardSwish()
#   (127): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#   (128): BatchNorm2d(672, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (129): HardSwish()
#   (130): AdaptiveAvgPool2d(output_size=1)
#   (131): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#   (132): HardSwish()
#   (133): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#   (134): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (135): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (136): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (137): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (138): HardSwish()
#   (139): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#   (140): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (141): HardSwish()
#   (142): AdaptiveAvgPool2d(output_size=1)
#   (143): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#   (144): HardSwish()
#   (145): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#   (146): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (147): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (148): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (149): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (150): HardSwish()
#   (151): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#   (152): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (153): HardSwish()
#   (154): AdaptiveAvgPool2d(output_size=1)
#   (155): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#   (156): HardSwish()
#   (157): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#   (158): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (159): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (160): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (161): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (162): HardSwish()
# ), Sequential(
#   (0): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (1): ReLU()
#   (2): Conv2d(960, 1920, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (3): ReLU(inplace=True)
#   (4): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): Conv2d(1920, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (6): ReLU(inplace=True)
#   (7): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(960, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (9): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): PixelShuffle(upscale_factor=2)
#   (11): ReplicationPad2d((1, 0, 1, 0))
#   (12): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (13): ReLU(inplace=True)
#   (14): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (15): Conv2d(272, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (16): ReLU(inplace=True)
#   (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): ReLU()
#   (19): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (20): PixelShuffle(upscale_factor=2)
#   (21): ReplicationPad2d((1, 0, 1, 0))
#   (22): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (23): ReLU(inplace=True)
#   (24): MergeLayer()
#   (25): Conv2d(259, 259, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (26): ReLU(inplace=True)
#   (27): Conv2d(259, 259, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (28): ReLU(inplace=True)
#   (29): MergeLayer()
#   (30): Conv2d(259, 3, kernel_size=(1, 1), stride=(1, 1))
#   (31): SigmoidRange()
# )], add_time=True, silent=False)

# %%
learn_gen.lr_find()
learn_gen.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
print("Upsize to gen_512")

do_fit(learn_gen, 1, gen_name+"_512px_0",slice(1e-5))
# Out:
# Upsize to gen_512
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.254381</td>
#       <td>0.198952</td>
#       <td>10:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.266117</td>
#       <td>0.204076</td>
#       <td>10:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.255998</td>
#       <td>0.201245</td>
#       <td>10:47</td>
#     </tr>
#   </tbody>
# </table>
